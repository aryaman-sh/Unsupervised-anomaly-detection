# %%
import torch
import torch.nn as nn

# %%
# TODO: Substitue ELBO
def ELBO(x):
    return 1

# %% [markdown]
# ![Screenshot%20from%202022-01-11%2021-20-36.png](attachment:Screenshot%20from%202022-01-11%2021-20-36.png)

# %%
def detect(Y, ELBO, T, alpha, n):
    """
    Y: Image with lesion
    ELBO: Trained prior
    T: masking threshold
    alpha: lerning rates per iteration step
    n: number of iterations
    """
    X = Y
    for i in range(0, n):
        loss1 = tv_loss = #tf.image.total_variation
        loss2 = elbo_loss = ELBO()
        
        grads = torch.autograd.gr
